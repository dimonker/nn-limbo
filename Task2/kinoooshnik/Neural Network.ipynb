# %% [markdown]
# # Задание 2.1 - Нейронные сети
#
# В этом задании вы реализуете и натренируете настоящую нейроную сеть своими руками!
#
# В некотором смысле это будет расширением прошлого задания - нам нужно просто составить несколько линейных классификаторов вместе!
#
# <img src="https://i.redd.it/n9fgba8b0qr01.png" alt="Stack_more_layers" width="400px"/>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
from dataset import load_svhn, random_split_train_val
from gradient_check import check_layer_gradient, check_layer_param_gradient, check_model_gradient
from layers import FullyConnectedLayer, ReLULayer
from model import TwoLayerNet
from trainer import Trainer, Dataset
from optim import SGD, MomentumSGD
from metrics import multiclass_accuracy

# %% [markdown]
# # Загружаем данные
#
# И разделяем их на training и validation.

# %%
def prepare_for_neural_network(train_X, test_X):
    train_flat = train_X.reshape(train_X.shape[0], -1).astype(np.float) / 255.0
    test_flat = test_X.reshape(test_X.shape[0], -1).astype(np.float) / 255.0
    
    # Subtract mean
    mean_image = np.mean(train_flat, axis = 0)
    train_flat -= mean_image
    test_flat -= mean_image
    
    return train_flat, test_flat
    
train_X, train_y, test_X, test_y = load_svhn("data", max_train=10000, max_test=1000)    
train_X, test_X = prepare_for_neural_network(train_X, test_X)
# Split train into train and val
train_X, train_y, val_X, val_y = random_split_train_val(train_X, train_y, num_val = 1000)

# %% [markdown]
# # Как всегда, начинаем с кирпичиков
#
# Мы будем реализовывать необходимые нам слои по очереди. Каждый слой должен реализовать:
# - прямой проход (forward pass), который генерирует выход слоя по входу и запоминает необходимые данные
# - обратный проход (backward pass), который получает градиент по выходу слоя и вычисляет градиент по входу и по параметрам
#
# Начнем с ReLU, у которого параметров нет.

# %%
# TODO: Implement ReLULayer layer in layers.py
# Note: you'll need to copy implementation of the gradient_check function from the previous assignment

X = np.array([[1,-2,3],
              [-1, 2, 0.1]
              ])

assert check_layer_gradient(ReLULayer(), X)
# Out:
# Gradient check passed!

# %% [markdown]
# А теперь реализуем полносвязный слой (fully connected layer), у которого будет два массива параметров: W (weights) и B (bias).
#
# Все параметры наши слои будут использовать для параметров специальный класс `Param`, в котором будут храниться значения параметров и градиенты этих параметров, вычисляемые во время обратного прохода.
#
# Это даст возможность аккумулировать (суммировать) градиенты из разных частей функции потерь, например, из cross-entropy loss и regularization loss.

# %%
# TODO: Implement FullyConnected layer forward and backward methods
assert check_layer_gradient(FullyConnectedLayer(3, 4), X)
# TODO: Implement storing gradients for W and B
assert check_layer_param_gradient(FullyConnectedLayer(3, 4), X, 'W')
assert check_layer_param_gradient(FullyConnectedLayer(3, 4), X, 'B')
# Out:
# Gradient check passed!
# Gradient check passed!
# Gradient check passed!

# %% [markdown]
# ## Создаем нейронную сеть
#
# Теперь мы реализуем простейшую нейронную сеть с двумя полносвязным слоями и нелинейностью ReLU. Реализуйте функцию `compute_loss_and_gradients`, она должна запустить прямой и обратный проход через оба слоя для вычисления градиентов.
#
# Не забудьте реализовать очистку градиентов в начале функции.

# %%
# TODO: In model.py, implement compute_loss_and_gradients function
model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 3, reg = 0)
loss = model.compute_loss_and_gradients(train_X[:2], train_y[:2])

# TODO Now implement backward pass and aggregate all of the params
check_model_gradient(model, train_X[:2], train_y[:2])
# Out:
# Checking gradient for W1
# Gradient check passed!
# Checking gradient for B1
# Gradient check passed!
# Checking gradient for W2
# Gradient check passed!
# Checking gradient for B2
# Gradient check passed!
# True

# %% [markdown]
# Теперь добавьте к модели регуляризацию - она должна прибавляться к loss и делать свой вклад в градиенты.

# %%
# TODO Now implement l2 regularization in the forward and backward pass
model_with_reg = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 3, reg = 1e1)
loss_with_reg = model_with_reg.compute_loss_and_gradients(train_X[:2], train_y[:2])
assert loss_with_reg > loss and not np.isclose(loss_with_reg, loss), \
    "Loss with regularization (%2.4f) should be higher than without it (%2.4f)!" % (loss, loss_with_reg)

check_model_gradient(model_with_reg, train_X[:2], train_y[:2])
# Out:
# Checking gradient for W1
# Gradient check passed!
# Checking gradient for B1
# Gradient check passed!
# Checking gradient for W2
# Gradient check passed!
# Checking gradient for B2
# Gradient check passed!
# True

# %% [markdown]
# Также реализуем функцию предсказания (вычисления значения) модели на новых данных.
#
# Какое значение точности мы ожидаем увидеть до начала тренировки?

# %%
# Finally, implement predict function!

# TODO: Implement predict function
# What would be the value we expect?
multiclass_accuracy(model_with_reg.predict(train_X[:30]), train_y[:30])
# Out:
# 0.16666666666666666

# %% [markdown]
# # Допишем код для процесса тренировки
#
# Если все реализовано корректно, значение функции ошибки должно уменьшаться с каждой эпохой, пусть и медленно. Не беспокойтесь пока про validation accuracy.

# %%
model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 100, reg = 1e1)
dataset = Dataset(train_X, train_y, val_X, val_y)
trainer = Trainer(model, dataset, SGD(), learning_rate = 1e-2)

# TODO Implement missing pieces in Trainer.fit function
# You should expect loss to go down every epoch, even if it's slow
loss_history, train_history, val_history = trainer.fit()
# Out:
# Loss: 2.302855, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.302223, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.301848, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.302641, Train accuracy: 0.148222, val accuracy: 0.140000
# Loss: 2.301473, Train accuracy: 0.099000, val accuracy: 0.093000
# Loss: 2.303081, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.303229, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.302748, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.301961, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.301103, Train accuracy: 0.148222, val accuracy: 0.140000
# Loss: 2.302513, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.302478, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.302768, Train accuracy: 0.148222, val accuracy: 0.140000
# Loss: 2.302385, Train accuracy: 0.148222, val accuracy: 0.140000
# Loss: 2.302013, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.302191, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.300245, Train accuracy: 0.148222, val accuracy: 0.140000
# Loss: 2.302475, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.301990, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.302166, Train accuracy: 0.196667, val accuracy: 0.206000

# %%
plt.plot(train_history)
plt.plot(val_history)

# %% [markdown]
# # Улучшаем процесс тренировки
#
# Мы реализуем несколько ключевых оптимизаций, необходимых для тренировки современных нейросетей.

# %% [markdown]
# ## Уменьшение скорости обучения (learning rate decay)
#
# Одна из необходимых оптимизаций во время тренировки нейронных сетей - постепенное уменьшение скорости обучения по мере тренировки.
#
# Один из стандартных методов - уменьшение скорости обучения (learning rate) каждые N эпох на коэффициент d (часто называемый decay). Значения N и d, как всегда, являются гиперпараметрами и должны подбираться на основе эффективности на проверочных данных (validation data).
#
# В нашем случае N будет равным 1.

# %%
# TODO Implement learning rate decay inside Trainer.fit method
# Decay should happen once per epoch

model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 100, reg = 1e-1)
dataset = Dataset(train_X, train_y, val_X, val_y)
trainer = Trainer(model, dataset, SGD(), learning_rate_decay=0.99)

initial_learning_rate = trainer.learning_rate
loss_history, train_history, val_history = trainer.fit()

assert trainer.learning_rate < initial_learning_rate, "Learning rate should've been reduced"
assert trainer.learning_rate > 0.5*initial_learning_rate, "Learning rate shouldn'tve been reduced that much!"
# Out:
# Loss: 2.285753, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.282430, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.218236, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.258859, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.235393, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.324395, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.217984, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.239600, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.242367, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.264284, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.267163, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.346773, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.326062, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.277073, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.251676, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.320428, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.338272, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.196595, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.323747, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.264590, Train accuracy: 0.196667, val accuracy: 0.206000

# %% [markdown]
# # Накопление импульса (Momentum SGD)
#
# Другой большой класс оптимизаций - использование более эффективных методов градиентного спуска. Мы реализуем один из них - накопление импульса (Momentum SGD).
#
# Этот метод хранит скорость движения, использует градиент для ее изменения на каждом шаге, и изменяет веса пропорционально значению скорости.
# (Физическая аналогия: Вместо скорости градиенты теперь будут задавать ускорение, но будет присутствовать сила трения.)
#
# ```
# velocity = momentum * velocity - learning_rate * gradient
# w = w + velocity
# ```
#
# `momentum` здесь коэффициент затухания, который тоже является гиперпараметром (к счастью, для него часто есть хорошее значение по умолчанию, типичный диапазон -- 0.8-0.99).
#
# Несколько полезных ссылок, где метод разбирается более подробно:
# http://cs231n.github.io/neural-networks-3/#sgd
# https://distill.pub/2017/momentum/

# %%
# TODO: Implement MomentumSGD.update function in optim.py

model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 100, reg = 1e-1)
dataset = Dataset(train_X, train_y, val_X, val_y)
trainer = Trainer(model, dataset, MomentumSGD(), learning_rate=1e-4, learning_rate_decay=0.99)

# You should see even better results than before!
loss_history, train_history, val_history = trainer.fit()
# Out:
# Loss: 2.321728, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.313053, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.318298, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.278634, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.312916, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.280987, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.282505, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.278731, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.279589, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.284135, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.266927, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.245125, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.289504, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.284567, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.281133, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.212597, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.304084, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.294143, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.279353, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.321648, Train accuracy: 0.196667, val accuracy: 0.206000

# %% [markdown]
# # Ну что, давайте уже тренировать сеть!

# %% [markdown]
# ## Последний тест - переобучимся (overfit) на маленьком наборе данных
#
# Хороший способ проверить, все ли реализовано корректно - переобучить сеть на маленьком наборе данных.
# Наша модель обладает достаточной мощностью, чтобы приблизить маленький набор данных идеально, поэтому мы ожидаем, что на нем мы быстро дойдем до 100% точности на тренировочном наборе.
#
# Если этого не происходит, то где-то была допущена ошибка!

# %%
data_size = 15
model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 100, reg = 1e-1)
dataset = Dataset(train_X[:data_size], train_y[:data_size], val_X[:data_size], val_y[:data_size])
trainer = Trainer(model, dataset, SGD(), learning_rate=1e-1, num_epochs=150, batch_size=5)

# You should expect this to reach 1.0 training accuracy 
loss_history, train_history, val_history = trainer.fit()
# Out:
# Loss: 2.335359, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.304101, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.310242, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.279115, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.281665, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.287292, Train accuracy: 0.200000, val accuracy: 0.066667
# Loss: 2.374577, Train accuracy: 0.266667, val accuracy: 0.000000
# Loss: 2.210017, Train accuracy: 0.266667, val accuracy: 0.000000
# Loss: 2.263800, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 2.216674, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 2.249326, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 2.068453, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 1.568579, Train accuracy: 0.333333, val accuracy: 0.000000
# Loss: 1.841748, Train accuracy: 0.333333, val accuracy: 0.000000
# Loss: 1.858708, Train accuracy: 0.333333, val accuracy: 0.000000
# Loss: 2.041495, Train accuracy: 0.333333, val accuracy: 0.000000
# Loss: 2.012344, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 1.737132, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 2.124478, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 1.586991, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 1.943991, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 2.083922, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 1.927954, Train accuracy: 0.466667, val accuracy: 0.066667
# Loss: 1.793886, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 1.419110, Train accuracy: 0.466667, val accuracy: 0.000000
# Loss: 2.195647, Train accuracy: 0.466667, val accuracy: 0.066667
# Loss: 1.435125, Train accuracy: 0.466667, val accuracy: 0.000000
# Loss: 1.651995, Train accuracy: 0.466667, val accuracy: 0.066667
# Loss: 2.038691, Train accuracy: 0.533333, val accuracy: 0.066667
# Loss: 1.632311, Train accuracy: 0.533333, val accuracy: 0.066667
# Loss: 2.032727, Train accuracy: 0.533333, val accuracy: 0.066667
# Loss: 1.839734, Train accuracy: 0.600000, val accuracy: 0.066667
# Loss: 1.847821, Train accuracy: 0.600000, val accuracy: 0.066667
# Loss: 1.680798, Train accuracy: 0.666667, val accuracy: 0.066667
# Loss: 1.729625, Train accuracy: 0.666667, val accuracy: 0.066667
# Loss: 1.926715, Train accuracy: 0.666667, val accuracy: 0.066667
# Loss: 1.655729, Train accuracy: 0.666667, val accuracy: 0.066667
# Loss: 1.810061, Train accuracy: 0.666667, val accuracy: 0.066667
# Loss: 1.594301, Train accuracy: 0.666667, val accuracy: 0.066667
# Loss: 1.968011, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 1.639907, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 1.198556, Train accuracy: 0.666667, val accuracy: 0.066667
# Loss: 2.024531, Train accuracy: 0.666667, val accuracy: 0.000000
# Loss: 1.052936, Train accuracy: 0.666667, val accuracy: 0.066667
# Loss: 1.126274, Train accuracy: 0.666667, val accuracy: 0.066667
# Loss: 1.070449, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 1.667665, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 1.535099, Train accuracy: 0.666667, val accuracy: 0.000000
# Loss: 1.270909, Train accuracy: 0.733333, val accuracy: 0.000000
# Loss: 1.559654, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 1.429657, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 1.261243, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 1.320957, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 1.600489, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 0.876446, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 1.227293, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 1.611441, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 1.365360, Train accuracy: 0.733333, val accuracy: 0.000000
# Loss: 1.417446, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 1.451483, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 1.158421, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 1.305083, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 1.811087, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 1.906823, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 1.272075, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 1.688168, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.275723, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.883545, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.898523, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.525137, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.522140, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.761549, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.285042, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.611973, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.578401, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.259981, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.453438, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.288008, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.548174, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.012797, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.283089, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.202924, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.478543, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.323874, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.282987, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.177144, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.433985, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 1.411486, Train accuracy: 0.866667, val accuracy: 0.000000
# Loss: 1.626895, Train accuracy: 0.866667, val accuracy: 0.000000
# Loss: 1.282843, Train accuracy: 0.866667, val accuracy: 0.000000
# Loss: 1.506119, Train accuracy: 0.866667, val accuracy: 0.000000
# Loss: 1.373495, Train accuracy: 0.866667, val accuracy: 0.000000
# Loss: 1.444534, Train accuracy: 0.866667, val accuracy: 0.000000
# Loss: 1.298771, Train accuracy: 0.866667, val accuracy: 0.000000
# Loss: 0.966585, Train accuracy: 0.866667, val accuracy: 0.000000
# Loss: 1.341232, Train accuracy: 0.866667, val accuracy: 0.000000
# Loss: 1.750136, Train accuracy: 0.866667, val accuracy: 0.000000
# Loss: 0.997393, Train accuracy: 0.866667, val accuracy: 0.000000
# Loss: 1.773118, Train accuracy: 0.866667, val accuracy: 0.000000
# Loss: 1.642722, Train accuracy: 0.866667, val accuracy: 0.000000
# Loss: 0.994573, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.338124, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.288150, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.291534, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.357104, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.326769, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.575979, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.164333, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.389475, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.316065, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.293179, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.353182, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.327013, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.254572, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.234711, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.416556, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.369461, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.208976, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.397447, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.328861, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.233570, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.110248, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.363927, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 0.976547, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 0.981146, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.593951, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.217670, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.307550, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.301741, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.343539, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.081410, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.210698, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.434772, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.266865, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.502025, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.220354, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.140156, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.260236, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.101928, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.234903, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.418565, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.238931, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.375191, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.216392, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.026919, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.431402, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.384416, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.257174, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.341249, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.226373, Train accuracy: 1.000000, val accuracy: 0.000000

# %% [markdown]
# Теперь найдем гипепараметры, для которых этот процесс сходится быстрее.
# Если все реализовано корректно, то существуют параметры, при которых процесс сходится в **20** эпох или еще быстрее.
# Найдите их!

# %%
# Now, tweak some hyper parameters and make it train to 1.0 accuracy in 20 epochs or less

model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 100, reg = 1e-1)
dataset = Dataset(train_X[:data_size], train_y[:data_size], val_X[:data_size], val_y[:data_size])
# TODO: Change any hyperparamers or optimizators to reach training accuracy in 20 epochs
trainer = Trainer(model, dataset, SGD(), learning_rate=0, num_epochs=20, batch_size=5)

loss_history, train_history, val_history = trainer.fit()
# Out:
# Loss: 2.333355, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.334434, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.333372, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.333857, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.333742, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.333354, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.333562, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.333073, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.332503, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.332903, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.332757, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.333642, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.333397, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.333293, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.333019, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.333315, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.333355, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.333755, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.332850, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.333237, Train accuracy: 0.200000, val accuracy: 0.133333

# %% [markdown]
# # Итак, основное мероприятие!
#
# Натренируйте лучшую нейросеть! Можно добавлять и изменять параметры, менять количество нейронов в слоях сети и как угодно экспериментировать.
#
# Добейтесь точности лучше **60%** на validation set.

# %%
# Let's train the best one-hidden-layer network we can

learning_rates = 1e-4
reg_strength = 1e-3
learning_rate_decay = 0.999
hidden_layer_size = 128
num_epochs = 200
batch_size = 64

best_classifier = None
best_val_accuracy = None

loss_history = []
train_history = []
val_history = []

# TODO find the best hyperparameters to train the network
# Don't hesitate to add new values to the arrays above, perform experiments, use any tricks you want
# You should expect to get to at least 40% of valudation accuracy
# Save loss/train/history of the best classifier to the variables above

model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 100, reg = 1e-4)
dataset = Dataset(train_X, train_y, val_X, val_y)
trainer = Trainer(model, dataset, MomentumSGD(), learning_rate=1e-1, num_epochs=20, batch_size=100)
loss_history, train_history, val_history = trainer.fit()
best_val_accuracy = np.mean(val_history)

print('best validation accuracy achieved: %f' % best_val_accuracy)
# Out:
# Loss: 2.146296, Train accuracy: 0.244667, val accuracy: 0.255000
# Loss: 1.719647, Train accuracy: 0.439000, val accuracy: 0.445000
# Loss: 1.264090, Train accuracy: 0.622667, val accuracy: 0.599000
# Loss: 1.295787, Train accuracy: 0.654889, val accuracy: 0.650000
# Loss: 1.129028, Train accuracy: 0.675111, val accuracy: 0.651000
# Loss: 1.086962, Train accuracy: 0.670444, val accuracy: 0.625000
# Loss: 0.996310, Train accuracy: 0.723778, val accuracy: 0.675000
# Loss: 1.039039, Train accuracy: 0.743889, val accuracy: 0.671000
# Loss: 0.860448, Train accuracy: 0.729667, val accuracy: 0.676000
# Loss: 1.080356, Train accuracy: 0.737556, val accuracy: 0.682000
# Loss: 0.744513, Train accuracy: 0.744444, val accuracy: 0.675000
# Loss: 0.768477, Train accuracy: 0.793444, val accuracy: 0.729000
# Loss: 0.877357, Train accuracy: 0.774556, val accuracy: 0.677000
# Loss: 0.966655, Train accuracy: 0.783778, val accuracy: 0.702000
# Loss: 0.888401, Train accuracy: 0.749333, val accuracy: 0.671000
# Loss: 0.506609, Train accuracy: 0.788111, val accuracy: 0.688000
# Loss: 0.883159, Train accuracy: 0.794889, val accuracy: 0.714000
# Loss: 0.801553, Train accuracy: 0.813333, val accuracy: 0.707000
# Loss: 0.723871, Train accuracy: 0.788556, val accuracy: 0.688000
# Loss: 0.819426, Train accuracy: 0.799000, val accuracy: 0.715000
# best validation accuracy achieved: 0.644750

# %%
plt.figure(figsize=(15, 7))
plt.subplot(211)
plt.title("Loss")
plt.plot(loss_history)
plt.subplot(212)
plt.title("Train/validation accuracy")
plt.plot(train_history)
plt.plot(val_history)

# %% [markdown]
# # Как обычно, посмотрим, как наша лучшая модель работает на тестовых данных

# %%
best_classifier = model

# %%
test_pred = best_classifier.predict(test_X)
test_accuracy = multiclass_accuracy(test_pred, test_y)
print('Neural net test set accuracy: %f' % (test_accuracy, ))
# Out:
# Neural net test set accuracy: 0.673000
